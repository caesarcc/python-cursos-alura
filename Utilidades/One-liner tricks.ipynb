# %%
# What are the top earners earning over
# $100k per month?

dic = {'Alice' : 100000,
       'Bob' : 99817,
       'Carol' : 122908,
       'Frank' : 88123,
       'Eve' : 93121}
# List Comprehension
res = [(k,v) for k,v in dic.items() if v>=100000]
print(res)
# Out:
# [('Alice', 100000), ('Carol', 122908)]

# %%
# Read a file and strip whitespaces
print([l.strip() for l in open("file.py")])
# ['print([l.strip() for l in open("file.py")])']

# %%
# Lambda, Map, and Ternary Operator
## Data
t = ['lambda functions are anonymous functions.',
     'anonymous functions dont have a name.',
     'functions are objects in Python.']
q = 'anonymous' # query

## One-Liner
mark = map(lambda s: (1, s) if q in s else (0, s), t)

## Result
print(list(mark))
# Out:
# [(1, 'lambda functions are anonymous functions.'), (1, 'anonymous functions dont have a name.'), (0, 'functions are objects in Python.')]

# %%
# Lambda, Ternary, Slicing
## Data
letters_amazon = '''
We spent several years building our own database engine,
Amazon Aurora, a fully-managed MySQL and PostgreSQL-compatible
service with the same or better durability and availability as
the commercial engines, but at one-tenth of the cost. We were
not surprised when this worked.
'''

## One-Liner
find = lambda txt, q: txt[txt.find(q)-18:txt.find(q)+18]

## Result
print(find(letters_amazon, 'SQL'))
# Out:
# a fully-managed MySQL and PostgreSQL

# %%
# List Comprehension + Slicing 

## Data (daily stock prices ($))
price = [[9.9, 9.8, 9.8, 9.4, 9.5, 9.7],
         [9.5, 9.4, 9.4, 9.3, 9.2, 9.1],
         [8.4, 7.9, 7.9, 8.1, 8.0, 8.0],
         [7.1, 5.9, 4.8, 4.8, 4.7, 3.9]]

## One-Liner
sample = [line[::2] for line in price]
## Result
print(sample)
# Out:
# [[9.9, 9.8, 9.5], [9.5, 9.4, 9.2], [8.4, 7.9, 8.0], [7.1, 4.8, 4.7]]

# %%
# Slice Assignments
## Data
visitors = ['Firefox', 'corrupted',
            'Chrome', 'corrupted',
            'Safari', 'corrupted',
            'Safari', 'corrupted',
            'Chrome', 'corrupted',
            'Firefox', 'corrupted']

## One-Liner
visitors[1::2] = visitors[::2]
## Result
print(visitors)
# Out:
# ['Firefox', 'Firefox', 'Chrome', 'Chrome', 'Safari', 'Safari', 'Safari', 'Safari', 'Chrome', 'Chrome', 'Firefox', 'Firefox']

# %%
# testando o step no slice
outros = ['Firefox', 'corrupted',
            'Chrome', 'corrupted',
            'Safari', 'corrupted',
            'Safari', 'corrupted',
            'Chrome', 'corrupted',
            'Firefox', 'corrupted']
print(outros[::2])
# Out:
# ['Firefox', 'Chrome', 'Safari', 'Safari', 'Chrome', 'Firefox']

# %%
# List Concatenation
## Dependencies
import matplotlib.pyplot as plt
## Data
cardiac_cycle = [62, 60, 62, 64, 68, 77,
                 80, 76, 71, 66, 61, 60, 62]
## One-Liner
expected_cycles = cardiac_cycle[1:-2] * 10
## Result
plt.plot(expected_cycles)
plt.show()
print(cardiac_cycle[1:-2])
print(expected_cycles)
# Out:
# [60, 62, 64, 68, 77, 80, 76, 71, 66, 61]
# [60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61, 60, 62, 64, 68, 77, 80, 76, 71, 66, 61]

# %%
# Generator Expression
## Companies
c = {'CoolCompany' : {'Alice' : 33,
                      'Bob' : 28,
                      'Frank' : 29},
     'CheapCompany' : {'Ann' : 4,
                       'Lee' : 9,
                       'Chrisi' : 7},
     'SosoCompany' : {'Esther' : 38,
                      'Cole' : 8,
                      'Paris' : 18}}

## One-Liner to find illegal companies
i = [x for x in c if any(y<9 for y in c[x].values())]
## Result
print(i)
# Out:
# ['CheapCompany', 'SosoCompany']

# %%
# Zip
## Data
cols = ['name', 'salary', 'job']
db = [('Alice', 180000, 'scientist'),
      ('Bob', 99000, 'manager'),
      ('Frank', 87000, 'CEO')]

## One-Liner
db = [dict(zip(cols, row)) for row in db]
## Result
print(db)

print(dict(zip(['nome', 'idade'], ['Caesar', '41'])))
# Out:
# [{'name': 'Alice', 'salary': 180000, 'job': 'scientist'}, {'name': 'Bob', 'salary': 99000, 'job': 'manager'}, {'name': 'Frank', 'salary': 87000, 'job': 'CEO'}]
# {'nome': 'Caesar', 'idade': '41'}

# %%
# Remove Dups
lst = [3, 3, 22, 22, 1]

dup_free = []
for x in lst:
    if x not in dup_free:
        dup_free.append(x)
print(dup_free)

print(list(dict.fromkeys(lst)))

# remove a ordem, set não tem ordem, se usar isto, 
# não faz sentido ter uma lista, sempre poderia ser um conjunto
print(list(set(lst)))
# Out:
# [3, 22, 1]
# [3, 22, 1]
# [1, 3, 22]
