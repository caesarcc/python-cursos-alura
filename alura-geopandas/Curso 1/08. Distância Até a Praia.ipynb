# %% [markdown]
# # Distância Até a Praia

# %% [markdown]
# ## Fontes

# %% [markdown]
# http://www.data.rio/
#
# http://www.data.rio/datasets/cobertura-vegetal-e-uso-da-terra-2016
#
# https://opendata.arcgis.com/datasets/a22768dc645043f5bdfd1affab888ded_0.geojson

# %%
# %matplotlib inline
import geopandas as gpd

# %%
#carrega o mapa de vegatção e uso do solo para identificar praias
praias = gpd.read_file('../Dados/Vegetação e Uso do Solo/Cobertura_Vegetal_e_Uso_da_Terra_2016.geojson')
#mapa do RJ
rj = gpd.read_file('../Dados/Mapas/RJ-MUNIC/RJ-MUNIC.shp')
#dataset de imóveis com todas modificações geradas até agora, com distancias até estações de transporte
geo_dados = gpd.read_file('../Dados/Mapas/RJ-DATASET/RJ-DATASET-TRANSPORTES.shp')

# %%
praias.head()
# Out:
#   Sigla                  ANO                     legenda   ShapeSTArea  \
# 0   Con  2016-01-01T00:00:00  Corpos d’água continentais   8684.890625
# 1   Con  2016-01-01T00:00:00  Corpos d’água continentais   2209.344727
# 2   Con  2016-01-01T00:00:00  Corpos d’água continentais  17015.344727
# 3   Con  2016-01-01T00:00:00  Corpos d’água continentais  17597.541016
# 4    Vg  2016-01-01T00:00:00  Vegetação gramíneo-lenhosa  11834.875977
#
#    ShapeSTLength  OBJECTID       GRUPO                      CLASSE FORMACOES  \
# 0     441.128326     19870      Outros  Corpos d’água continentais
# 1     241.436403     19871      Outros  Corpos d’água continentais
# 2     468.728882     19872      Outros  Corpos d’água continentais
# 3     916.463204     19873      Outros  Corpos d’água continentais
# 4     605.329142     19874  Antropismo  Vegetação gramíneo-lenhosa
#
#   ESTAGIO_SUCESSIONAL  SMAC"RIO\02497196"Mapeamento_CoberturaArea  \
# ...

# %%
praias.crs
# Out:
# {'init': 'epsg:4326'}

# %%
#converte sistema de coordenadas
praias = praias.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')
praias.crs
# Out:
# '+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs'

# %%
#plota a geometria do uso de solos
praias.plot(color='white', edgecolor='black', figsize=(15, 8))

# %%
#mostra distribuição de frequencias das legendas de cada geometria no dataset de uso de solo e vegetação
praias['legenda'].value_counts()
# Out:
# Vegetação arbórea não florestal                                     3495
# Vegetação gramíneo-lenhosa                                          2022
# Floresta Ombrófila Densa, Estágio Inicial                            643
# Áreas Urbanas                                                        639
# Afloramento Rochoso                                                  474
# Uso agrícola, Lavoura Permanente                                     445
# Floresta Ombrófila Densa, Estágio Médio                              414
# Corpos d’água continentais                                           388
# Reflorestamento                                                      252
# Formação Pioneira com influência flúvio-lacustre, Brejo herbáceo     210
# Uso agrícola, Lavoura Temporária                                     164
# Formação Pioneira com influência flúvio-marinha, Manguezal           161
# Solo exposto                                                         152
# ...

# %%
#limita o dataset somente as legendas que identificam praias
praias = praias[praias['legenda'] == 'Praia']

# %%
#plota os polígonos de praias sobre o mapa base do RJ
base = rj.plot(color='white', edgecolor='silver', alpha=0.4, figsize=(15, 8))
praias.plot(ax=base, color='white', edgecolor='black')

# %%
#gera coluna da menor distância da geometria de cada ponto de imóvel até os polígonos de praias em KM
geo_dados['Dist_Praia'] = geo_dados['geometry'].apply(lambda x: praias.distance(x).min())

# %%
geo_dados.head()
# Out:
#    Area                    Bairro          Cidade  \
# 0   138  Recreio dos Bandeirantes  Rio de Janeiro
# 1   133   Freguesia (Jacarepaguá)  Rio de Janeiro
# 2    46                   Pilares  Rio de Janeiro
# 3    65           Barra da Tijuca  Rio de Janeiro
# 4   260  Recreio dos Bandeirantes  Rio de Janeiro
#
#                          Endereco Estado   Latitude  Longitude  Quartos  \
# 0             Rua Vicente Scofano     RJ -23.016455 -43.462946        3
# 1                   Rua Potiguara     RJ -22.943199 -43.336911        3
# 2   Rua Professor Carneiro Felipe     RJ -22.873849 -43.300517        1
# 3        Avenida Salvador Allende     RJ -22.984787 -43.412703        2
# 4  Rua Desembargador Paulo Alonso     RJ -23.018927 -43.477505        3
#
#    Suites  Vagas         Tipo Transacao    Valor  Dist_Metro  Dist_Trans  \
# 0       1      3  Apartamento     Venda  1095000   15.622939    0.443193
# 1       1      2  Apartamento     Venda   650000    7.530741    3.642787
# ...

# %%
geo_dados.corr()
# Out:
#                 Area  Latitude  Longitude   Quartos    Suites     Vagas  \
# Area        1.000000 -0.289299   0.029982  0.681112  0.585817  0.594699
# Latitude   -0.289299  1.000000   0.292822 -0.225226 -0.346480 -0.274707
# Longitude   0.029982  0.292822   1.000000 -0.016882 -0.221548 -0.283960
# Quartos     0.681112 -0.225226  -0.016882  1.000000  0.529611  0.520499
# Suites      0.585817 -0.346480  -0.221548  0.529611  1.000000  0.621140
# Vagas       0.594699 -0.274707  -0.283960  0.520499  0.621140  1.000000
# Valor       0.724397 -0.299038   0.191868  0.481216  0.464075  0.456596
# Dist_Metro -0.036671 -0.217864  -0.874788  0.021794  0.188521  0.215787
# Dist_Trans -0.042684  0.358735  -0.031812 -0.014628  0.006363  0.070240
# Dist_Praia -0.290745  0.560701  -0.317743 -0.185829 -0.196554 -0.104570
#
#                Valor  Dist_Metro  Dist_Trans  Dist_Praia
# Area        0.724397   -0.036671   -0.042684   -0.290745
# Latitude   -0.299038   -0.217864    0.358735    0.560701
# ...

# %%
geo_dados.to_file('../Dados/Mapas/RJ-DATASET/RJ-DATASET-FINAL.shp')
