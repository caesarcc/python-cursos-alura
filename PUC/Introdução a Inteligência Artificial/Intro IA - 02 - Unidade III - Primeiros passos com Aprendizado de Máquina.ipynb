# %% [markdown]
# ## Regressão Linear

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([4, 2, 1, 3, 8, 7, 6, 5])
plt.scatter(x, y);

# %%
# Nesse nosso conjunto de dados sintético, vamos fazer um experimento simples

# Modelo de regreção
from sklearn.linear_model import LinearRegression

# Preparando dados
X = x.reshape(-1, 1)

# Instanciação e treinamento do modelo
model = LinearRegression().fit(X, y)

# Prediz os valores
yfit = model.predict(X)

# Gráfico
plt.scatter(x, y)
plt.plot(x, yfit);

# %%
# Essa classe é utilizada para geração de features usando polinômios (x², x³)
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=False)
X2 = poly.fit_transform(X)
print(X2)
# Out:
# [[  1.   1.   1.]
#  [  2.   4.   8.]
#  [  3.   9.  27.]
#  [  4.  16.  64.]
#  [  5.  25. 125.]
#  [  6.  36. 216.]
#  [  7.  49. 343.]
#  [  8.  64. 512.]]

# %%
# Retreinando o modelo
model = LinearRegression().fit(X2, y)
yfit = model.predict(X2)
plt.scatter(x, y)
plt.plot(x, yfit)

# %% [markdown]
# ## Decision Tree

# %%
# Utilizando o algoritimo de regressão em árvore com o dataset com as funções polinomiais adicionadas
## Decision Tree
from sklearn.tree import DecisionTreeRegressor

# Treina o modelo de Árvore de Decisão
model = DecisionTreeRegressor().fit(X2, y)

# Prediz os valores
yfit2 = model.predict(X2)

# Gráfico
plt.scatter(x, y)
plt.plot(x, yfit2);

# %%
# Vamos printar a nossa árvore de decisão para ficar mais claro o funcionamento

# Import de algumas libs necessárias
from sklearn.tree import export_graphviz
import graphviz

# Usando função do sklearn para exportar a árvore
dot_data = export_graphviz(model, out_file=None, filled=True, rounded=True,
                special_characters=True)

# Gerando visualização no IPython Notebook
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ## Objetivo: Criar um novo conjunto de dados sintéticos (conforme exemplo) com pelo menos 20 instâncias
#
# Testar os mesmos algoritmos e visualizar a qualidade do modelo que criaram com esses novos dados. Foi possível encontrar automáticamente uma função que modela esses dados?

# %%
# Coloque os valores para x dentro dos "[]", separados por "," - Ex.: [1, 2, 3]
x = np.array([])
# Coloque os valores para y dentro dos "[]", separados por "," - Ex.: [2, 4, 6]
y = np.array([])
plt.scatter(x, y);

# %%
# Preparando dados
X = x.reshape(-1, 1)

# Instanciação e treinamento do modelo
model = LinearRegression().fit(X, y)

# Predição da função
yfit = model.predict(X)

# Gráfico
plt.scatter(x, y)
plt.plot(x, yfit);
