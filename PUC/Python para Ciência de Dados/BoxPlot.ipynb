# %% [markdown]
# **matplotlib** - Lib para geração de gráficos em python
# **%** - Comando mágico para exibir os gráficos diretamente na tela
# **pandas** - Lib para gerar um dataframe simulado

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
dados = [[10,50],[12,90],[15,70],[24,90],[25,70],[30,65],[30,75],[50,90],[60,100],[71,95],[75,100],[80,80],[175,90]]
df = pd.DataFrame(dados, range(0, 13), ["N", "S"])
df
# Out:
#       N    S
# 0    10   50
# 1    12   90
# 2    15   70
# 3    24   90
# 4    25   70
# 5    30   65
# 6    30   75
# 7    50   90
# 8    60  100
# 9    71   95
# 10   75  100
# 11   80   80
# 12  175   90

# %%
df.describe()
# Out:
#                 N           S
# count   13.000000   13.000000
# mean    51.307692   81.923077
# std     47.115788   15.074601
# min     10.000000   50.000000
# 25%     24.000000   70.000000
# 50%     30.000000   90.000000
# 75%     71.000000   90.000000
# max    185.000000  100.000000

# %%
df.plot.box()
